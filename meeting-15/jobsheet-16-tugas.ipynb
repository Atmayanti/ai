# %%
url = 'https://www.gutenberg.org/cache/epub/66928/pg66928-images.html'

# %%
import requests

# %%
r = requests.get(url)
type(r)
# Out:
# requests.models.Response

# %%
requests?

# %%
html = r.text
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en">
# <head>
# <meta charset="utf-8">
# <meta name="generator" content="HTML Tidy for HTML5 for Linux version 5.6.0">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=yes">
# <title>The Project Gutenberg eBook of The Ranger Boys and Their Reward, by Claude A. Labelle</title>
#
# <style>body {
#     margin-left: 8%;
#     margin-right: 8%
#     }
# p {
#     text-indent: 1.15em;
#     margin-top: 0.1em;
#     margin-bottom: 0.1em;
#     text-align: justify
#     }
# .i {
#     font-style: italic
#     }
# h1 {
#     text-align: center;
#     font-weight: normal;
#     font-size: 1.4em;
#     margin-top: 3em;
#     margin-bottom: 1em
#     }
# h2 {
#     text-align: center;
#     font-weight: normal;
#     page-break-before: always;
#     font-size: 1em;
#     margin-top: 3em;
#     margin-bottom: 1.4em;
#     margin-left: auto;
#     margin-right: auto
#     }
# h2.nobreak {
# ...

# %%
# Mengimpor BeautifulSoup dari bs4
from bs4 import BeautifulSoup

# Membuat objek BeautifulSoup dari HTML
soup = BeautifulSoup(html, "html5lib")
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.title
# Out:
# <title>The Project Gutenberg eBook of The Ranger Boys and Their Reward, by Claude A. Labelle</title>

# %%
soup.title.string
# Out:
# 'The Project Gutenberg eBook of The Ranger Boys and Their Reward, by Claude A. Labelle'

# %%
soup.findAll('a')[:8]
# Out:
# [<a href="https://www.gutenberg.org">www.gutenberg.org</a>,
#  <a href="https://www.gutenberg.org">www.gutenberg.org</a>,
#  <a href="https://www.gutenberg.org/donate/">www.gutenberg.org/donate</a>,
#  <a href="https://www.gutenberg.org">www.gutenberg.org</a>]

# %%
text = soup.get_text()
print(text)
# Out:
# The Project Gutenberg eBook of The Ranger Boys and Their Reward, by Claude A. Labelle
#
# body {
#     margin-left: 8%;
#     margin-right: 8%
#     }
# p {
#     text-indent: 1.15em;
#     margin-top: 0.1em;
#     margin-bottom: 0.1em;
#     text-align: justify
#     }
# .i {
#     font-style: italic
#     }
# h1 {
#     text-align: center;
#     font-weight: normal;
#     font-size: 1.4em;
#     margin-top: 3em;
#     margin-bottom: 1em
#     }
# h2 {
#     text-align: center;
#     font-weight: normal;
#     page-break-before: always;
#     font-size: 1em;
#     margin-top: 3em;
#     margin-bottom: 1.4em;
#     margin-left: auto;
#     margin-right: auto
#     }
# h2.nobreak {
#     page-break-before: avoid
#     }
# div.cbline {
#     margin-left: 1.4em;
#     text-indent: -1.4em
#     }
# /* image dimensions */
# .w001 {
#     margin-left: 15%;
#     width: 70%
#     }
# .x-ebookmaker .w001 {
#     margin-left: 5%;
#     width: 90%
#     }
# .w002 {
#     margin-left: 40%;
# ...

# %%
pip install -U nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk 
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
# Import paket regex
import re

# Definisikan sentence
sentence = 'peter piper pick a peck of picked of pickled peppers'

# Definisikan regex
ps = 'p\w+'

# Mencari semua kata di sentence yang cocok dengan regex kemudian cetak
re.findall(ps, sentence)
# Out:
# ['peter', 'piper', 'pick', 'peck', 'picked', 'pickled', 'peppers']

# %%
re.findall('\w+', sentence)
# Out:
# ['peter',
#  'piper',
#  'pick',
#  'a',
#  'peck',
#  'of',
#  'picked',
#  'of',
#  'pickled',
#  'peppers']

# %%
tokens = re.findall('\w+', text)
tokens[:8]
# Out:
# ['The', 'Project', 'Gutenberg', 'eBook', 'of', 'The', 'Ranger', 'Boys']

# %%
# Impor RegexpTekenizer dari nltk.tokenize
from nltk.tokenize import RegexpTokenizer

# Buat tokenizer
tokenizer = RegexpTokenizer('\w+')

# Buat tokens
tokens = tokenizer.tokenize(text)
tokens[:8]
# Out:
# ['The', 'Project', 'Gutenberg', 'eBook', 'of', 'The', 'Ranger', 'Boys']

# %%
# Menginisalisasi ke dalam list
words = []

# Loop dari list tokens dan buat huruf kecil/lower case
for word in tokens:
    words.append(word.lower())
    
# Cetak beberapa :
words[:8]
# Out:
# ['the', 'project', 'gutenberg', 'ebook', 'of', 'the', 'ranger', 'boys']

# %%
# Impor modul nltk
import nltk
nltk.download('stopwords')

# Get English stopwords and print some of them
sw = nltk.corpus.stopwords.words('english')
sw[:5]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ATMAYANTI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we']

# %%
# Menginisialisasi ke dalam list
word_ns = []

# Tambahkan ke word_ns semua kata yang ada dalam words 
# tetapi tidak dalam sw
for word in words:
    if word not in sw :
        word_ns.append(word)
    
# Cetak beberapa
word_ns[:5]
# Out:
# ['project', 'gutenberg', 'ebook', 'ranger', 'boys']

# %%
# Impor datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline dan setting style visualisasi
# %matplotlib inline
sns.set()

# Buat frekuensi distribusi dan plot 25 kata
freqdist1 = nltk.FreqDist(word_ns)
freqdist1.plot(25)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Impor datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline dan setting style visualisasi
# %matplotlib inline
sns.set()

# Buat frekuensi distribusi dan plot 25 kata
freqdist1 = nltk.FreqDist(word_ns)
freqdist1.plot(35)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
# Impor datavis libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Figures inline dan setting style visualisasi
# %matplotlib inline
sns.set()

# Buat frekuensi distribusi dan plot 25 kata
freqdist1 = nltk.FreqDist(word_ns)
freqdist1.plot(10)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>
